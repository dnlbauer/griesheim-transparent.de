# %%
import json
import numpy as np
import pandas as pd
import re

# %%
data = []
with open("frontend/test.json", "r", encoding="utf-8") as f:
    for line in f.readlines():
        data.append(json.loads(line))
        
data = pd.DataFrame(data)
data.head()
# Out:
#   id         last_analyzed  document_id    size     content_type
# 0  1  2023-05-06T14:02:29Z         6164  169369  application/pdf  \
# 1  2  2023-05-06T14:02:29Z          553   99102  application/pdf
# 2  3  2023-05-06T14:02:29Z          722  183796  application/pdf
# 3  4  2023-05-06T14:02:29Z         3961  331258  application/pdf
# 4  5  2023-05-06T14:02:29Z          723  267877  application/pdf
#
#                      doc_title agenda_item_id agenda_item_title
# 0          Stvv01 - 14.04.2011             []                []  \
# 1                   1 Pro-JSKS             []                []
# 2  Kostenplan 2013-12 Mai 2016             []                []
# 3             Niederschrift SB             []                []
# 4                   2 Pro-Schw             []                []
#
#   agenda_item_text meeting_id  ...         creation_date
# 0               []     [1413]  ...  2017-11-30T12:08:04Z  \
# 1               []       [69]  ...  2016-05-26T05:49:28Z
# 2               []       [76]  ...  2016-05-10T07:46:01Z
# 3               []     [1220]  ...  2017-03-20T14:30:09Z
# 4               []       [76]  ...  2016-08-12T09:23:49Z
#
#           last_modified            last_saved       doc_type consultation_id
# 0  2017-11-30T12:08:04Z  2017-11-30T12:08:04Z            NaN             NaN  \
# 1  2016-05-26T05:49:28Z  2016-05-26T05:49:28Z            NaN             NaN
# 2  2016-05-10T09:32:42Z  2016-05-10T09:32:42Z            NaN             NaN
# 3  2017-03-20T14:30:09Z  2017-03-20T14:30:09Z  Niederschrift             NaN
# 4  2016-08-12T09:23:49Z  2016-08-12T09:23:49Z            NaN             NaN
#
#   consultation_name consultation_type consultation_text consultation_topic
# 0               NaN               NaN               NaN                NaN  \
# 1               NaN               NaN               NaN                NaN
# 2               NaN               NaN               NaN                NaN
# 3               NaN               NaN               NaN                NaN
# 4               NaN               NaN               NaN                NaN
#
#    consultation_organization
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 31 columns]

# %%
data.doc_type.unique()
# Out:
# array([nan, 'Niederschrift', 'Beschlussvorlage', 'Antragsvorlage',
#        'Informationsvorlage'], dtype=object)

# %%
def iterate_content(doc_type=None, document_ids=None):
    if doc_type:
        filtered = data[data.doc_type == doc_type]
    else:
        filtered = data
    
    if document_ids:
        filtered = filtered[np.isin(filtered.document_id, document_ids)]
    
    for (document_id, content) in zip(filtered["document_id"], filtered["content"]):
        yield (document_id, content)
        

def remove_by_regexes(content, regexes):
    """ Removes the header of documents based on given regex patterns.
    The content lines are scanned for the first occurance of all regexes and the returned output
    contains only the content after the last regex match.
    Therefore, if a regex is found twice, only the first match is considered.
    If two regexes match, the content is cut for the last match of the two.
    """
    matches = []  # tuples (line, regex_end) for all first matches
    for regex in regexes:
        for idx, line in enumerate(content):
            res = re.search(regex, line)
            if res:
                matches.append((idx, res.end()))
                break

    last_match_line = np.max([match[0] for match in matches])
    last_match_inline = 0
    for line, inline in matches:
        if line != last_match_line:
            continue
        last_match_inline = np.max([last_match_inline, inline])
        
    content = content[last_match_line:]
    content[0] = content[0][last_match_inline:]
    if content[0].strip == "":
        content = content[1:]
    return content

# test remove_by_regexes:
result = remove_by_regexes([
    "first line",
    "second line with match in middle",
    "third line with match in middle",
    "fourth line"
], [r"with match", "third line"])

assert result == [" with match in middle", "fourth line"]

# %% [markdown]
# # Antragsvorlage

# %%
# create a test dataset for antrag header removal test
antraege = data[data.doc_type == "Antragsvorlage"]
print("dataset size", len(antraege))
data_set_identifiers = [
    lambda x: "die Stadtverordnetenversammlung möge beschließen:" in x and x.endswith(":"),
    lambda x: "die Stadtverordnetenversammlung möge beschließen" in x and "beschließen:" not in x,
    lambda x: "die Stadtverordnetenversammlung möge beschließen" in x and len(x) > 100,
    lambda x: "Wir beantragen. die Stadtverordnetenversammlung möge beschließen" in x,
    lambda x: "bitte nehmen Sie den folgenden Antrag zur Beratungen auf die Tagesordnung" in x,
]
selected_ids = []
ids = []
for identifier in data_set_identifiers:
    for id, content in zip(antraege.document_id.values, antraege.content.values):
        for line in content:
             if identifier(line):
                ids.append(id)
                break
    selected_ids += np.random.choice(ids, size=1).tolist()


print(f"test set size {len(selected_ids)}")
# Out:
# dataset size 228
# test set size 5

# %%
selector = np.isin(antraege.document_id, selected_ids)
for doc_id, content in iterate_content(doc_type="Antragsvorlage", document_ids=selected_ids):
    print(doc_id)
    result = remove_by_regexes(content, [
        r"die Stadtverordnetenversammlung möge beschließen[\s\:\.,]*",
        r"Sehr geehrte[r]? (Herr|Frau) Stadtverordnetenvorsteher(in)?[\s\.,]*",
    ])
    print("".join(result)[:100], "...")
    print("")
    print("\n".join(content))

    print("=-----------------------------------------==")
# Out:
# 23449
# Die Straßenbeitragssatzung der Stadt Griesheim vom 14.12.2012 wird aufgehoben. Eine neue Satzung wir ...
#
# SPD-Stadtverordnetenfraktion Griesheim
# SPD-Stadtverordnetenfraktion Ingrid Zimmermann, Goethestr. 30, 64347 Griesheim
# Frau Stadtverordnetenvorsteherin Martina Bott Wilhelm-Leuschner-Str. 75 64347 Griesheim
# :.-.
# •
# 11. MAI 2018
# dtverordnet.envor.stehe
# 07.05.2018
# SPD-Antrag Nr. 15: Aufhebung der Straßenbeitragssatzung
# Sehr geehrte Frau Bott, ich bitte Sie, folgenden Antrag auf die Tagesordnung der nächsten Sitzung der Stadtverordnetenversammlung zu setzen.
# Wir beantragen, die Stadtverordnetenversammlung möge beschließen:
# Die Straßenbeitragssatzung der Stadt Griesheim vom 14.12.2012 wird aufgehoben. Eine neue Satzung wird nicht beschlossen.
# Begründung:
# Erfolgt mündlich Mit freundlichen Grüßen
# Fraktionsvorsitzende
# SPD-Stadtverordnetenfraktion Griesheim
# Fraktionsvorsitzende Ingrid Zimmermann, Goethestr. 30, 64347 Griesheim Tel.: 06155-6914, Email: zimmermann-griesheim@t-onfine.de
# =-----------------------------------------==
# 23421
# Der Punkt 7. Budgetüberwachung wird um einen neuen Unterpunkt ergänzt:7.3. Den Finanzberichten ist e ...
#
# 090/0IE GRÜNEN, FRIEDRICH-EBERT-STR. 90, 64347 GRIESHEIM
# An die Stadtverordnetenvorsteherin Frau Martina Bott
# Rathaus - Parlamentarisches Büro Wilhelm-Leuschner-Strasse 75
# D - 64347 Griesheim
# 1 9. OKT. 2017
# dtverordne�envo�stahe
# BÜNDNIS 90 DIE GRÜNEN
# BÜNDNIS 90 / DIE GRÜNEN Fraktion Griesheim
# Friedrich-Ebert-Strasse 90 64347 Griesheim fraktion@gruene-griesheim.de
# Fraktionsvorsitzender
# Andreas Tengicki
# stellv. Fraktionsvorsitzende
# Ramona Halbrock
# Griesheim, 17.10.2017
# Antrag zu BV2017/0552 - Nachtragshaushalt
# NH2017-1: Budgetüberwachung
# Sehr geehrte Frau Stadtverordnetenvorsteherin, bitte nehmen Sie den folgenden Antrag zu den Beratungen des Nachtragshaushalts auf die nächste Sitzung des WiFi und der nächsten Stadtverordnetenversammlung.
# Wir beantragen, die Stadtverordnetenversammlung möge beschließen:
# Der Punkt 7. Budgetüberwachung wird um einen neuen Unterpunkt ergänzt:
# 7.3. Den Finanzberichten ist eine kurze zusammenfassende Darstellung der wesent­ lichsten Entwicklungen und Abweichungen, verbunden mit einer Einschätzung wie diese sich auf das Jahresergebnis auswirken, beizufügen.
# Zusätzlich beinhalten die Finanzberichte eine Übersicht über den Stand und die Verwendung der im Rahmen des Punktes 6.4. übertragenen Mittel.
# Begründung:
# Im Sinne eines Berichts(wesens) ist es aus unserer Sicht für die Stadtverordneten und die Bürger sinnvoll, wenn zu Beginn der Finanzberichte eine Übersicht der wesentlichen Ent­ wicklungen erfolgt. Mit dem Ziel „die Zahlen(kolonnen) zu übersetzen" und das „Wesentliche vom Unwesentlichen unterscheiden zu können". Diese Darstellung soll - wie bereits vor eini­ ger Zeit bereits einmal vereinbart - eine Seite nicht überschreiten.
# Zusätzlich zu den S&D im Produkt 09.01.01 Stadtplanung (277Tsd€) werden nun auch die S&D beim Produkt 01.01.14 (neu 3,852 Mio€) dauerhaft für übertragbar erklärt, dies sind 2017 4.129 Mio€ oder fast 34% der S&D. Die übertragbaren S&D sind Bestandteil eines Teil­ budgets(Produkt), die mit anderen Teilbudgets(Produkten) eines Budgets(Fachbereichs) ge­ genseitige Deckungsfähig sind und gleichzeitig die Teilbudgets wiederum aus Teilprodukten bestehen, die auch untereinander Deckungsfähig sind (=> Deckungsfähigkeit „nach unten und oben").
# BÜNDNIS 90 DIE GRÜNEN
# Um über die Haushaltsjahre hinweg nachvollziehen zu können, für welche Produkte/Teilpro­ dukte die übertragenen Mittel verwendet werden sollen bzw. werden, ist eine tabellarische Übersicht über den Stand der übertragenen Mittel zu den Finanzberichten hilfreich bzw. er­ forderlich (mögliche Gliederung: Teilprodukt/Übertrag/davon bisher ausgezahlt/davon bisher vergeben/noch verfügbar)
# =-----------------------------------------==
# 23457
# Der Magistrat wird beauftragt in der nächsten Sitzung des Ausschusses für Umwelt, Energie und Mobili ...
#
# 690/DIE GRÜNEN, FRIEDRICH-EBERT-STR. 90, 64347 GRIESHEIM
# An den Stadtverordnetenvorsteherin Frau Bott
# Rathaus - Parlamentarisches Büro Wilhelm-Leuschner-Strasse 75
# D - 64347 Griesheim
# A-6/ J0481001-9
# BÜNDNIS90 DIE GRÜNEN
# BÜNDNIS 90 / DIE GRÜNEN Fraktion Griesheim
# Friedrich-Ebert-Strasse 90 64347 Griesheim fraktion@gruene-griesheim.de
# 10. AUG. 2018 Fraktionsvorsitzender
# Andreas Tengicki
# stellv. Fraktionsvorsitzende
# Ramona Halbrock
# Griesheim, 8.8.2018
# Stand der Umsetzung und Pflege der städtischen Ausgleichs­
# und Ersatzmaßnahmen für Eingriffe in Natur und Landschaft
# Sehr geehrte Frau Stadtverordnetenvorsteherin, bitte nehmen Sie den folgenden Antrag zur Beratungen auf die Tagesordnung der nächsten Sitzung der Stadtverordnetenversammlung.
# Wir beantragen, die Stadtverordnetenversammlung möge beschließen:
# Der Magistrat wird beauftragt in der nächsten Sitzung des Ausschusses für Umwelt, Energie und Mobilität über den Stand der umsetzung und Pflege der städtischen Ausgleichs- und Er­ satzmaßnahmen für Eingriffe in Natur und Landschaft zu berichten. Diesem Bericht vorangestellt soll ein Überblick zu Lage, Größe und auszugleichendem Ein­ griff (z.B. Aufstellung eines BPlans, wie beispielsweise BPlan „Westring", oder andere Ein­ griffe) der einzelnen Maßnahmen erfolgen, sowie eine Auskunft zum Stand des städtischen Ökopunktekontos.
# Begründung:
# Die Eingriffs-Ausgleichs-Regelung ist eines der wichtigsten Instrumente zur Durchsetzung von Belangen des Naturschutzes in Deutschland. Durch sie sollen die negativen Auswirkun­ gen von Eingriffen in die Natur vermieden und minimiert werden. Nicht vermeidbare Eingriffe sind durch Maßnahmen für den Naturschutz zu kompensieren. Die in Bplan-Verfahren verbindlich festgelegten Ausgleichs- und Ersatzmaßnahmen sollen spätestens mit der Ausführung des Eingriffes (= Umsetzung der Planung) umgesetzt werden. Um Funktion und Wirkung der Ausgleichs- und Ersatzmaßnahmen dauerhaft zu sichern, sind entsprechende Pflege- und Unterhaltungsmaßnahmen erforderlich, die regelmäßig im Rah­ men der Eingriffsgenehmigung verpflichtend festgesetzt werden.. Im Sinne eines nachhaltigen Naturschutzes einerseits und rechtsgültigen Bebauungsplänen und einer vorausschauenden Planung der finanziellen Aufwendungen andererseits ist es wichtig, die Umsetzung der Maßnahmen und deren Pflege in regelmäßigen Abständen zu überprüfen.
# =-----------------------------------------==
# 27077
# Die Stadtverordnetenversammlung betont ihr Interesse, möglichst bald in Griesheim einen "Naturkinder ...
#
# Eingegangen 12.11.2020 Stadtverordnetenvorsteherin Griesheim
# B90/DIE GRÜNEN, PFUNGSTÄDTER STR. 40, 64347 GRIESHEIM
# Frau Stadtverordnetenvorsteherin Martina Bott Rathaus - Parlamentarisches Büro Wilhelm-Leuschner-Str.75 64347 Griesheim
# AG / 2020 / 0124
# BÜNDNIS 90 / DIE GRÜNEN
# Fraktion Griesheim
# Pfungstädter Straße 40
# 64347 Griesheim
# fraktion@gruene-griesheim.de
# Fraktionsvorsitzende
# Ramona Halbrock
# stellv. Fraktionsvorsitzende
# Christine Roßmann
# Griesheim, 12.11.2020
# Kinderbetreuung ausbauen – Standortermittlung für einen Naturkindergarten
# Sehr geehrte Frau Stadtverordnetenvorsteherin, bitte nehmen Sie den folgenden Antrag auf die Tagesordnung der nächsten Sitzung der Stadtverordnetenversammlung.
# Der Antrag soll im Ausschuss für Jugend, Soziales, Kultur und Sport vorberaten werden.
# Wir beantragen, die Stadtverordnetenversammlung möge beschließen:
# Die Stadtverordnetenversammlung betont ihr Interesse, möglichst bald in Griesheim einen "Naturkindergarten" als weiteres Betreuungsangebot für Kinder zu schaffen.
# Der Magistrat wird beauftragt, zur Standortermittlung für die Einrichtung eines Naturkindergartens ein darin erfahrenes Büro zu beauftragen.
# Begründung:
# Natur- und Waldkindergärten bzw. -kindergartengruppen sind inzwischen eine etablierte Betreuungsform in Deutschland und darüber hinaus. Entsprechende Einrichtungen in unserer näheren Umgebung befinden sich unter anderem in DA-Eberstadt und MörfeldenWalldorf. Bickenbach plant, nach einer Standortermittlung durch Externe, einen Naturkindergarten. Größe, Einwohnerzahl und (Bevölkerungs-)Struktur Griesheims legen nahe, dass für eine solche Einrichtung auch hier eine ausreichende Nachfrage vorhanden ist.
# Natur- und Waldkindergärten bzw. -kindergartengruppen sind darüber hinaus relativ kurzfristig realisierbar. Für eine zeitnahe Ermittlung möglicher Standorte soll ein darin erfahrenes Büro beauftragt werden.
# Der Bedarf an Kinderbetreuungsplätzen und damit an zusätzlichen Einrichtungen steigt in Griesheim auf absehbare Zeit weiter an. Ziel ist, den Eltern ein möglichst breites, vielfältiges und damit passendes Betreuungsangebot zu bieten und auf der anderen Seite auch die Verwaltung zu entlasten.
# 201112 B90GRUENE_ANTRAG_NaturKiTa_Standort.docx Seite 1 von 2
# Der erfolgreiche Betrieb einer Kinderbetreuungseinrichtung erfordert einen entsprechenden
# Vorlauf und Vorbereitung. Nach der Klärung der Standortfrage ist der nächste Schritt, einen freien Träger z.B. über ein Interessenbekundungsverfahren zu finden. Die Anbieter sollen darlegen, mit welcher Ausrichtung, Konzept und Einrichtungsgröße Interesse am Betrieb eines Naturkindergartens in Griesheim besteht und welche Erfahrungen mit dieser Betreuungsform vorhanden sind. Im Anschluss daran kann entschieden werden, ob und mit welchem Träger ggf. über eine Vergabe verhandelt werden kann.
# Mit freundlichen Grüßen
# Ramona Halbrock
# Fraktionsvorsitzende
# 201112 B90GRUENE_ANTRAG_NaturKiTa_Standort.docx Seite 2 von 2
# =-----------------------------------------==
# 42955
# Der Magistrat wird beauftragt, jährlich an mind. 10 – immer gleichen - Punkten mittels Seitenradar d ...
#
# Eingegangen AG / 2022 / 0067
# 24.08.2022 Stadtverordnetenvorsteherin Griesheim
# B90/DIE GRÜNEN, MAINSTRASSE 3A, 64347 GRIESHEIM
# An die Stadtverordnetenvorsteherin Frau Zimmermann
# Rathaus - Parlamentarisches Büro Wilhelm-Leuschner-Straße 75
# D – 64347 Griesheim
# BÜNDNIS 90 / DIE GRÜNEN Fraktion Griesheim
# Mainstraße 3A
# 64347 Griesheim fraktion@gruene-griesheim.de
# Fraktionsführung
# Martin Tichy Thorsten Eisele Andreas M. Heydt Christine Roßmann
# Griesheim, 23.8.2022
# Regelmäßige Verkehrsdatenerfassung
# Sehr geehrte Frau Stadtverordnetenvorsteherin, bitte nehmen Sie den folgenden Antrag auf die Tagesordnung der nächsten Sitzung der Stadtverordnetenversammlung.
# Wir beantragen, die Stadtverordnetenversammlung möge beschließen:
# Der Magistrat wird beauftragt, jährlich an mind. 10 – immer gleichen - Punkten mittels Seitenradar die Verkehrsmengen und -geschwindigkeiten zu messen und über die Ergebnisse im zuständigen Ausschuss für Umwelt, Mobilität und Energie zu berichten.
# Der Antrag soll vorab im zuständigen Ausschuss für Umwelt, Mobilität und Energie beraten werden.
# Begründung:
# Der (motorisierte) Verkehr und die von ihm ausgehenden Belastungen sind der Grund für regelmäßige Diskussionen und – mehr oder weniger – sachliche Auseinandersetzungen auf der einen Seite und Anlass für Anstrengungen diese zu reduzieren auf der anderen. Ganz allgemein erfährt man in Gesprächen, dass kaum eine Bürger*in mit der allgemeinen Verkehrssituation in der Stadt und insbesondere den gefahrenen Geschwindigkeiten zufrieden ist. Um die Diskussionen zu versachlichen und die Anstrengungen besser einschätzen und ggf. (nach)steuernd einzugreifen ist es mit entscheidend die Verkehrsentwicklung zu beobachten und zu analysieren. Griesheim verfügt bisher über keine flächendeckende und wiederkehrende Verkehrsdatenerfassung mittels regelmäßiger Zählungen oder fester Messstellen. Mit dem Seitenradar steht uns jedoch ein relativ einfaches Mittel zur Verfügung, mit dem aus unserer Sicht, mit dem vorhandenen Personal eine Anzahl von mindestens 10 Messstellen jährlich erfasst werden kann. An mind. 10 in Abstimmung von Magistrat und den zuständigen Ämtern der Stadt festzulegenden Stellen, sollen ebenfalls noch abzustimmend mind. 1x jährlich für mind. eine Woche (besser zwei) zu vergleichbaren & repräsentativen Zeiten (außerhalb der Schulferien – nicht im Winter oder Hochsommer) die Verkehrsmengen und -geschwindigkeiten erfasst werden. Diese Messungen sind kein Ersatz für bzw. sollen die bisherigen Seitenradarmessungen „nach Anlass" nicht einschränken, sondern um eine kontinuierliche und systematische Betrachtung ergänzen.
# Mit Hilfe des Seitenradars können die verschiedenen Fahrzeugarten (auch Fahrräder) und die gefahrenen Geschwindigkeiten in beide Richtungen ermittelt und speichert werden. Sie
# sind so unauffällig, dass sie das Verkehrsverhalten nicht beeinflussen. Sollte die Anzahl der verfügbaren Geräte für diese systematischen Messungen nicht ausreichen, sind weitere im kommenden Haushalt zu finanzieren und anschließend zu beschaffen.
# Wir erhoffen und erwarten uns dadurch für die Verwaltung und die Politik Aussagen zu Entwicklungen und Veränderungen bezüglich Verkehrsmenge, -mittel und -geschwindigkeit. Deshalb ist es aus unserer Sicht richtig und wichtig, wenn die Ergebnisse einmal jährlich öffentlich präsentiert und zugänglich gemacht werde. Nicht erst die Radverkehrsanalyse und das Klimaschutzkonzept haben deutlich gemacht wie wichtig es ist als Stadt besonders die innerstädtischen Verkehre (<5km) in den Focus zu nehmen, hier werden große Potentiale zu Vermeidung und Verlagerung auf eine nicht motorisierte Fortbewegung erwartet.
# gez. Martin Tichy
# =-----------------------------------------==

# %% [markdown]
# # Beschlussvorlagen

# %%
beschlussvorlagen = data[(data.doc_type == "Beschlussvorlage")]
beschlussvorlagen.head()

# create test dataset for beschlussvorlagen header removal
print("dataset size", len(beschlussvorlagen))
data_set_identifiers = [
    lambda x: "Der Stadtverordnetenversammlung wird folgende Beschlussfassung empfohlen:" in x
]
selected_ids = []
ids = []
for identifier in data_set_identifiers:
    for id, content in zip(beschlussvorlagen.document_id.values, beschlussvorlagen.content.values):
        for line in content:
             if identifier(line):
                ids.append(id)
                break
    print(ids)
    selected_ids += np.random.choice(ids, size=1).tolist()

selected_ids.append(27230) # special case: bürgermeister
print(f"test set: {selected_ids}")
# Out:
# dataset size 56
# [3790, 1215, 1216, 496, 3004, 2716, 2705, 1693, 2703, 3993, 432, 1203, 1056, 4643, 5884, 4885, 20076, 17398, 27202, 27230, 26910, 21879, 31737, 29128, 28567, 28541, 28569, 28568, 28570, 28571, 28566, 28695, 36200, 28972, 28931, 28940, 43073]
# test set: [2705, 27230]

# %%
selector = np.isin(beschlussvorlagen.document_id, selected_ids)
for doc_id, content in zip(beschlussvorlagen.document_id[selector], beschlussvorlagen.content[selector]):
    print(doc_id)
    result = remove_by_regexes(content, [
        r"die Stadtverordnetenversammlung möge beschließen[\s\:\.,]*",
        r"wird folgende Beschlussfassung empfohlen[\s\:\.,]*",
    ])
    
    print("".join(result)[:100], "...")
    print("")
    print("\n".join(content))

    print("=-----------------------------------------==")
# Out:
# 2705
# Die 2. Änderungssatzung zur Wasserversorgungssatzung (WVS) vom 17.12.2012 wird beschlossen. Sie trit ...
#
# Vorlage an die Stadtverordnetenversammlung der Stadt Griesheim
# Beschlussvorlage Steuer- und Gebührenamt öffentlich
# Wasserversorgung, 2. Änderungssatzung zur Wasserversorgungssatzung (WVS)
# Beratungsfolge Magistrat Wirtschafts- und Finanzausschuss Stadtverordnetenversammlung 17.10.2016 03.11.2016
# BV/2016/0172
# nicht öffentlich Vorberatung öffentlich Vorberatung öffentlich Entscheidung Der Stadtverordnetenversammlung wird folgende Beschlussfassung empfohlen:
# Die 2. Änderungssatzung zur Wasserversorgungssatzung (WVS) vom 17.12.2012 wird beschlossen. Sie tritt am Tage nach ihrer Bekanntmachung in Kraft.
# Begründung / Erläuterungen: Aufgrund des entsprechenden Auftrags hat die Firma Schüllermann und Partner AG in Dreieich die Höhe des Wasserbeitrags neu kalkuliert. Da der gegenwärtige Wasserbeitrag bereits seit mehreren Jahren unverändert ist, ist eine Aktualisierung des Beitrags vor allem im Hinblick auf die Erschließung des „Wohngebiets Südwest" und anderer kleinerer Neubaugebiete geboten.
# Hauptgründe sind zum einen die Sicherstellung der Beitragserhebung im Rahmen der Globalkalkulation und zum anderen das Standhalten bei einer eventuellen gerichtlichen Überprüfung.
# Die Kalkulation des Wasserbeitrags führt zu dem Ergebnis, dass sich der Beitrag um 0,88 € von seither 2,05 € auf künftig 1,17 € pro Quadratmeter Grundstücks- und Geschossfläche vermindert.
# Mit der Änderung des § 26 Abs. 1 Satz 1 WVS wird lediglich die gängige Praxis umgesetzt, wonach der Aufwand für die reine Unterhaltung der Anschlussleitungen nicht von den Anschlussnehmern zu erstatten ist. Hier erfolgt die Finanzierung über die Wassergebühren.
# Weiterhin ist die Erhöhung der Kaution für die Entleihung von Standrohren erforderlich. Bedingt durch die kostenintensivere Anschaffung neuer Standrohre, die jetzt mit einem Systemtrenner versehen sind, dient die Erhöhung der Kaution von bisher 250,00 € auf künftig 500,00 € der finanziellen Sicherheit der Stadtwerke. Mit dem Systemtrenner wird den Vorschriften der Trinkwasserverordnung genüge getan, indem diese Einrichtung den Rückfluss von möglicherweise verschmutztem Wasser in das städtische Trinkwassernetz verhindert.
# Produkt: 11.03.01 Wasserversorgung Finanzielle Auswirkungen einmalig: Anlagen: WVS-ÄND2 2016 Griesheim, den 20.10.2016 gez.
# Seite 1 von 2
# Finanzielle Auswirkungen laufend: Wirtschaftlichkeitsbetrachtung: Alternativen:
# Gabriele Winter Bürgermeisterin
# «voname» Seite 2 von 2
# =-----------------------------------------==
# 27230
# 1. Das Investitionsprogramm wird im Bereich des Produktbereichs 12 zum Produkt Stadtplanung öffentli ...
#
# Vorlage an die Stadtverordnetenversammlung der Stadt Griesheim
# Beschlussvorlage Fachbereich 2 Finanzen öffentlich
# H 2 - Antrag des Bürgermeisters zum Haushalt 2021 BV/2020/1824
# Beratungsfolge Wirtschafts- und Finanzausschuss Stadtverordnetenversammlung 26.11.2020 öffentlich Vorberatung öffentlich Entscheidung Der Stadtverordnetenversammlung wird folgende Beschlussfassung empfohlen:
# 1. Das Investitionsprogramm wird im Bereich des Produktbereichs 12 zum Produkt Stadtplanung öffentliche Verkehrsflächen 12.01.01 wie folgt erweitert: Investitions-Nummer: 1201012105 Investition: Errichtung Lärmschutzwall Wohngebiet Süd-West Investitionssumme: 1.462.510,00 Euro 2. Im Bereich des Produktbereichs 16 – Allgemeine Finanzwirtschaft wird zum Produkt Steuern, allgemeine Zuweisungen, allgemeine Umlagen eine Zuweisung des Bundes in Höhe von 1.316.259 Euro eingeplant. 3. Im Bereich des Produktbereichs 01 – Innere Verwaltung wird zum Produkt Liegenschaftsverwaltung der Investitionsbetrag zur Investitions-Nummer 010117202100 um 146.251 Euro reduziert.
# Begründung / Erläuterungen: Begründung / Erläuterungen: Nach Aufstellung und Einbringung des Haushaltsentwurfes 2021 wurde bekannt, dass infolge der Teilnahme am Förderprogramm des Bundes "Modellprojekte zur Klimaanpassung und Modernisierung in urbanen Räumen – Konzeption zur Förderung von Parks und Grünanlagen" die Planungsvorschläge der Stadtverwaltung Griesheim für die Ausgestaltung des im Bebauungsplan vorgesehenen Lärmschutzwalls berücksichtigt wurden. Die hierfür ausgewiesene nicht rückzahlbare Bundeszuwendung beträgt rd. 1,3 Mio. Euro, die Maßnahme ist im nächsten Haushaltsjahr 2021 umzusetzen.
# Die von der Verwaltung grob ermittelten Baukosten für den Wall belaufen sich brutto auf 1.462.510,00 Euro, von denen der Bund nach den Bedingungen des Wettbewerbs 90% übernimmt. Bei der Stadt verbleibt ein Eigenanteil von 10%, entsprechend 146.251,00 Euro. Da in der Kalkulation auch Pflegeaufwand in Höhe von 10.000,00 Euro enthalten ist, der nicht als Investition geplant werden kann, ist der Restbetrag von 136.251,00 Euro als Eigenanteil der Investition zu tragen. Dieser Betrag kann aus dem für den Grundstückserwerb vorgesehenen Betrag von 12 Mio. Euro entnommen werden, der sich entsprechend auf 11.863.749,00 Euro reduziert.
# Um dieser Zusage und der damit verbundenen notwendigen Änderung des Haushaltsentwurfs Die Genehmigungsfähigkeit des Haushaltes wird durch diese Änderung voraussichtlich nicht betroffen.
# Seite 1 von 2
# Rechnung zu tragen und dies noch rechtzeitig in die Haushaltsberatungen der Stadtverordnetenversammlung einfließen lassen zu können, habe ich mich entschlossen die vorstehenden Anträge zur Veränderung des Haushaltsentwurfes zu stellen.
# Produkt: Finanzielle Auswirkungen einmalig: Finanzielle Auswirkungen laufend: Wirtschaftlichkeitsbetrachtung: Alternativen: Anlagen: Antragsschreiben Bürgermeister_25.11.2020 Griesheim, den 25.11.2020 gez.
# Geza Krebs-Wetzl Bürgermeister
# «voname» Seite 2 von 2
# =-----------------------------------------==

# %% [markdown]
# # Informationsvorlagen

# %%
informationsvorlagen = data[(data.doc_type == "Informationsvorlage")]
informationsvorlagen.head()

# create test dataset for beschlussvorlagen header removal
print("dataset size", len(informationsvorlagen))
data_set_identifiers = [
    lambda x: "Die Stadtverordnetenversammlung wird über folgendes Thema informiert:" in x
]
selected_ids = []
ids = []
for identifier in data_set_identifiers:
    for id, content in zip(informationsvorlagen.document_id.values, informationsvorlagen.content.values):
        for line in content:
            if identifier(line):
               ids.append(id)
               break
    print(ids)
    selected_ids += np.random.choice(ids, size=1).tolist()

print(f"test set: {selected_ids}")
# Out:
# dataset size 27
# [2806, 3943, 698, 1180, 7053, 11550, 4381, 40421, 46995, 47177, 47158]
# test set: [4381]

# %%
selector = np.isin(informationsvorlagen.document_id, selected_ids)
for doc_id, content in zip(informationsvorlagen.document_id[selector], informationsvorlagen.content[selector]):
    print(doc_id)
    result = remove_by_regexes(content, [
        r"Die Stadtverordnetenversammlung wird über folgendes Thema informiert:[\s\:\.,]*",
    ])
    
    print("".join(result)[:100], "...")
    print("")
    print("\n".join(content))

    print("=-----------------------------------------==")
# Out:
# 4381
# Ein Antwortschreiben des Vorstandes der Frankfurter Volksbank zur Resolution liegt vor und ist als A ...
#
# Vorlage an die Stadtverordnetenversammlung der Stadt Griesheim
# Informationsvorlage Fachbereich 1 Zentrale Dienste öffentlich
# Resolution zum Erhalt der Filiale der Frankfurter Volksbank in der Bessunger Straße
# Beratungsfolge Stadtverordnetenversammlung 11.05.2017 öffentlich
# IV/2017/0059
# Kenntnisnahme Die Stadtverordnetenversammlung wird über folgendes Thema informiert:
# Ein Antwortschreiben des Vorstandes der Frankfurter Volksbank zur Resolution liegt vor und ist als Anlage beigefügt.
# Begründung / Erläuterungen: In der letzten Stadtverordnetenversammlung wurde eine Resolution zum Erhalt der Filiale der Frankfurter Volksbank in der Bessunger Straße beschlossen. Diese wurde dem Vorstand der Frankfurter Volksbank übermittelt.
# Produkt:01.01.02 Städtische Gremien Anlagen: Resolution VOBA Schreiben Griesheim, den 03.05.2017 gez.
# Geza Krebs-Wetzl Bürgermeister
# Seite 1 von 1
# =-----------------------------------------==
